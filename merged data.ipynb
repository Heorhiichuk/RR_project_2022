# %%
import pandas as pd
import numpy as np
import seaborn as sns
import gc
import random 
import matplotlib.pyplot as plt
import statsmodels.api as sm
import warnings
import math
plt.style.use('seaborn-ticks')
# %matplotlib inline

# %%
import os
import warnings
os.getcwd()
# Out:
# 'C:\\Users\\tetiana.heorhiichuk'

# %% [markdown]
# How data look like

# %%
pd.concat([df_v,df_d], axis=1)
# Out:
#     Sygnatura czasowa;I am currently employed at least part-time;I identify as having a mental illness;Education;I have my own computer separate from a smart phone;I have been hospitalized before for my mental illness;How many days were you hospitalized for your mental illness (Put 0 if you never been hospitalized);I am legally disabled;I have my regular access to the internet;I live with my parents;I have a gap in my resume;Total length of any gaps in my resume in months (Put 0 if you never had any gaps in my resume in months);Annual income (including any social welfare programs) in złoty;I am unemployed;I read outside of work and school;Annual income from social welfare programs (Put 0 if you never recieved from social welfare programs);I receive food stamps;I am on section 8 housing (social housing);How many times were you hospitalized for your mental illness (Put 0 if you never been hospitalized);Lack of concentration;Anxiety;Depression;Obsessive thinking;Mood swings;Panic attack
# ...

# %%
df_v = pd.read_csv("Mental Health Analysis (Odpowiedzi).csv")
df_d = pd.read_csv("Cleaned-Data.csv")
df = pd.merge(df_v, df_d, how='outer', left_on=True, right_on=True)

df.set_index('I am currently employed at least part-time', inplace = True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\TETIAN~1.HEO\AppData\Local\Temp/ipykernel_18440/2879937731.py in <module>
#       1 df_v = pd.read_csv("Mental Health Analysis (Odpowiedzi).csv")
#       2 df_d = pd.read_csv("Cleaned-Data.csv")
# ----> 3 df = pd.merge(df_v, df_d, how='outer', left_on=True, right_on=True)
#       4
#       5 df.set_index('I am currently employed at least part-time', inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ...

# %%
# Out:
#    I am currently employed at least part-time  \
# 0                                           0
# 1                                           1
# 2                                           1
# 3                                           0
# 4                                           1
#
#    I identify as having a mental illness                Education  \
# 0                                      0       High School or GED
# 1                                      1                 Some Phd
# 2                                      0  Completed Undergraduate
# 3                                      0       Some Undergraduate
# 4                                      1  Completed Undergraduate
#
#    I have my own computer separate from a smart phone  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# ...
